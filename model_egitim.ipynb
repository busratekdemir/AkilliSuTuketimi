# %% [markdown]
# # SmartWater – ML Modellerinin Eğitimi ve Değerlendirilmesi
# Bu defterde iki farklı tahmin modeli eğitilecek ve performans metrikleri karşılaştırılarak en iyi model seçilecektir.

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
df = pd.read_csv("data/temiz_su_tuketimi_ml_ready.csv")
print("Temiz veri seti yüklendi.")
df.head()
# Out:
# Temiz veri seti yüklendi.
#     YIL  AY  ORTALAMA_TUKETIM_MEAN  ABONE_ADEDI_SUM  KAYIT_SAYISI  \
# 0  2024   1                  170.5              7.0           1.0
# 1  2022  10                  170.5              7.0           1.0
# 2  2021   8                  170.5              7.0           1.0
# 3  2022   1                   58.0              1.0           1.0
# 4  2021   3                 1457.0             56.0           1.0
#
#    ORT_DOLULUK    TOPLAM_SU  BARAJ_SAYISI  TUKETIM
# 0    35.190000  280086000.0           6.0    76.62
# 1    40.355000  303945000.0           6.0   148.10
# 2    48.658333  348099000.0           6.0   132.88
# 3    52.893333  324869000.0           6.0   141.36
# 4    69.538333  440241000.0           6.0   111.44

# %% [markdown]
# Bağımlı ve Bağımsız Değişkenlerin Ayrılması

# %%
X = df.drop("TUKETIM", axis=1)   # → Özellikler
y = df["TUKETIM"]                # → Tahmin edilecek değer

print("X boyutu:", X.shape)
print("y boyutu:", y.shape)
# Out:
# X boyutu: (1350, 8)
# y boyutu: (1350,)

# %% [markdown]
# Train-Test Split İşlemi

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size = 0.20,   # → verinin %20’si test için ayrıldı
    random_state = 42   # → tekrarlanabilirlik
)

print("Eğitim seti:", X_train.shape)
print("Test seti   :", X_test.shape)
# Out:
# Eğitim seti: (1080, 8)
# Test seti   : (270, 8)

# %% [markdown]
# MODEL 1: Lineer Regresyonun Eğitilmesi

# %%
linear_model = LinearRegression()
linear_model.fit(X_train, y_train)

y_pred_lr = linear_model.predict(X_test)

# Metrikler
mae_lr  = mean_absolute_error(y_test, y_pred_lr)
rmse_lr = mean_squared_error(y_test, y_pred_lr) ** 0.5
r2_lr   = r2_score(y_test, y_pred_lr)

print("----- Lineer Regresyon Sonuçları -----")
print("MAE :", round(mae_lr, 2))
print("RMSE:", round(rmse_lr, 2))
print("R²  :", round(r2_lr, 4))
# Out:
# ----- Lineer Regresyon Sonuçları -----
# MAE : 34.03
# RMSE: 43.34
# R²  : -0.0063

# %% [markdown]
# MODEL 2: Random Forest Regressor’ın Eğitilmesi

# %%
rf_model = RandomForestRegressor(
    n_estimators = 200,
    random_state = 42
)

rf_model.fit(X_train, y_train)
y_pred_rf = rf_model.predict(X_test)

# Metrikler
mae_rf  = mean_absolute_error(y_test, y_pred_rf)
rmse_rf = mean_squared_error(y_test, y_pred_rf) ** 0.5
r2_rf   = r2_score(y_test, y_pred_rf)

print("----- Random Forest Sonuçları -----")
print("MAE :", round(mae_rf, 2))
print("RMSE:", round(rmse_rf, 2))
print("R²  :", round(r2_rf, 4))
# Out:
# ----- Random Forest Sonuçları -----
# MAE : 36.8
# RMSE: 47.88
# R²  : -0.2278

# %% [markdown]
# MODEL 3: Support Vector Regression (SVR)

# %%
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler

# SVR ölçeklendirme ister → X verisini scale edelim
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

svr_model = SVR(kernel="rbf", C=100, gamma=0.1)

svr_model.fit(X_train_scaled, y_train)
y_pred_svr = svr_model.predict(X_test_scaled)

mae_svr  = mean_absolute_error(y_test, y_pred_svr)
rmse_svr = mean_squared_error(y_test, y_pred_svr) ** 0.5
r2_svr   = r2_score(y_test, y_pred_svr)

print("----- SVR Sonuçları -----")
print("MAE :", round(mae_svr, 2))
print("RMSE:", round(rmse_svr, 2))
print("R²  :", round(r2_svr, 4))
# Out:
# ----- SVR Sonuçları -----
# MAE : 35.19
# RMSE: 44.77
# R²  : -0.0734

# %% [markdown]
# MODEL 4: KNN Regressor

# %%
from sklearn.neighbors import KNeighborsRegressor

knn_model = KNeighborsRegressor(n_neighbors=5)
knn_model.fit(X_train, y_train)

y_pred_knn = knn_model.predict(X_test)

mae_knn  = mean_absolute_error(y_test, y_pred_knn)
rmse_knn = mean_squared_error(y_test, y_pred_knn) ** 0.5
r2_knn   = r2_score(y_test, y_pred_knn)

print("----- KNN Regrasyon Sonuçları -----")
print("MAE :", round(mae_knn, 2))
print("RMSE:", round(rmse_knn, 2))
print("R²  :", round(r2_knn, 4))
# Out:
# ----- KNN Regrasyon Sonuçları -----
# MAE : 37.13
# RMSE: 48.13
# R²  : -0.2406

# %% [markdown]
# MODEL 5: Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

dt_model = DecisionTreeRegressor(
    max_depth=None,
    random_state=42
)

dt_model.fit(X_train, y_train)
y_pred_dt = dt_model.predict(X_test)

mae_dt  = mean_absolute_error(y_test, y_pred_dt)
rmse_dt = mean_squared_error(y_test, y_pred_dt) ** 0.5
r2_dt   = r2_score(y_test, y_pred_dt)

print("----- Decision Tree Sonuçları -----")
print("MAE :", round(mae_dt, 2))
print("RMSE:", round(rmse_dt, 2))
print("R²  :", round(r2_dt, 4))
# Out:
# ----- Decision Tree Sonuçları -----
# MAE : 41.38
# RMSE: 53.92
# R²  : -0.5572

# %% [markdown]
# TÜM MODELLERİN KARŞILAŞTIRMA TABLOSU

# %%
results = pd.DataFrame({
    "Model": [
        "Lineer Regresyon",
        "Random Forest",
        "SVR",
        "KNN Regressor",
        "Decision Tree"
    ],
    "MAE":  [mae_lr, mae_rf, mae_svr, mae_knn, mae_dt],
    "RMSE": [rmse_lr, rmse_rf, rmse_svr, rmse_knn, rmse_dt],
    "R²":   [r2_lr, r2_rf, r2_svr, r2_knn, r2_dt]
})

results
# Out:
#               Model        MAE       RMSE        R²
# 0  Lineer Regresyon  34.032925  43.344515 -0.006264
# 1     Random Forest  36.804624  47.879336 -0.227835
# 2               SVR  35.190398  44.767313 -0.073410
# 3     KNN Regressor  37.125578  48.128271 -0.240635
# 4     Decision Tree  41.382335  53.919914 -0.557192

# %% [markdown]
# En iyi modelin seçilmesi

# %%
best_model = results.loc[results["RMSE"].idxmin()]
print("📌 En iyi model:")
print(best_model)
# Out:
# 📌 En iyi model:
# Model    Lineer Regresyon
# MAE             34.032925
# RMSE            43.344515
# R²              -0.006264
# Name: 0, dtype: object

# %%
import os
import json
import joblib
from sklearn.linear_model import LinearRegression

linear_model = LinearRegression()
linear_model.fit(X_train, y_train)

os.makedirs("ml_service/artifacts", exist_ok=True)

joblib.dump(linear_model, "ml_service/artifacts/best_model.joblib")

feature_cols = list(X.columns)
with open("ml_service/artifacts/feature_cols.json", "w", encoding="utf-8") as f:
    json.dump(feature_cols, f, ensure_ascii=False)

print("✅ Model ve feature listesi kaydedildi")
print("→ ml_service/artifacts/best_model.joblib")
print("→ ml_service/artifacts/feature_cols.json")
# Out:
# ✅ Model ve feature listesi kaydedildi
# → ml_service/artifacts/best_model.joblib
# → ml_service/artifacts/feature_cols.json

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\DELL\\PycharmProjects\\SmartWaterML'

# %%
import joblib

# En iyi model olan linear_model'i kaydediyoruz
joblib.dump(linear_model, 'ml_service/artifacts/su_tahmin_modeli.pkl')
print("✅ Model 'su_tahmin_modeli.pkl' olarak kaydedildi!")
# Out:
# ✅ Model 'su_tahmin_modeli.pkl' olarak kaydedildi!
